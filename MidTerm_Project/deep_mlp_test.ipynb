# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
import mock_data 
import utilities as tool
import mlp
import importlib

importlib.reload(mock_data)
importlib.reload(mlp)
importlib.reload(tool)

# 创建数据集
data = mock_data.MockData()
dataSet1, labels1 = data.create_linear_data()
dataSet2, labels2 = data.create_stochastic_data()
train_input1, test_input1, train_target1, test_target1 = train_test_split(dataSet1, labels1, test_size = 0.2)
train_input2, test_input2, train_target2, test_target2 = train_test_split(dataSet2, labels2, test_size = 0.2)

# mlp的训练
input_dim = 2
epoch_num = 1000
bn_mode = False
tol = None
optimize_type = 0
batch_size = 1
reg = 0

# 用线性分布数据训练模型验证模型正确性
print('training linear data')
layer_num = 3
unit_num = [6, 2, 1]
learning_rate = 0.1
model = mlp.MLP(input_dim, layer_num, unit_num)
model.train(train_input1, train_target1, epoch_num, learning_rate, tol, optimize_type, batch_size, reg, bn_mode)
tool.plot_decision_boundary(np.array(dataSet1), np.array(labels1), model, 'layer3 few neuron')

layer_num = 3
unit_num = [12, 6, 1]
learning_rate = 0.1
model = mlp.MLP(input_dim, layer_num, unit_num)
model.train(train_input1, train_target1, epoch_num, learning_rate, tol, optimize_type, batch_size, reg, bn_mode)
tool.plot_decision_boundary(np.array(dataSet1), np.array(labels1), model, 'layer3 more neuron')

layer_num = 6
unit_num = [15, 12, 9, 6, 3, 1]
learning_rate = 0.1
model = mlp.MLP(input_dim, layer_num, unit_num)
model.train(train_input1, train_target1, epoch_num, learning_rate, tol, optimize_type, batch_size, reg, bn_mode)
tool.plot_decision_boundary(np.array(dataSet1), np.array(labels1), model, 'layer6 few neuron')

layer_num = 6
unit_num = [30, 24, 18, 6, 3, 1]
learning_rate = 0.01
model = mlp.MLP(input_dim, layer_num, unit_num)
model.train(train_input1, train_target1, epoch_num, learning_rate, tol, optimize_type, batch_size, reg, bn_mode)
tool.plot_decision_boundary(np.array(dataSet1), np.array(labels1), model, 'layer6 more neuron')

layer_num = 9
unit_num = [60, 42, 36, 30, 24, 18, 6, 3, 1]
learning_rate = 0.001
model = mlp.MLP(input_dim, layer_num, unit_num)
model.train(train_input1, train_target1, epoch_num, learning_rate, tol, optimize_type, batch_size, reg, bn_mode)
tool.plot_decision_boundary(np.array(dataSet1), np.array(labels1), model, 'layer9 few neuron')

unit_num = [6, 18, 24, 30, 24, 18, 6, 3, 1]
learning_rate = 0.001
model = mlp.MLP(input_dim, layer_num, unit_num)
model.train(train_input1, train_target1, epoch_num, learning_rate, tol, optimize_type, batch_size, reg, bn_mode)
tool.plot_decision_boundary(np.array(dataSet1), np.array(labels1), model, 'layer9 more neuron')

# 用随机数数据训练模型
layer_num = 3
epoch_num = 10000
unit_num = [6, 2, 1]
learning_rate = 0.01
model = mlp.MLP(input_dim, layer_num, unit_num)
model.train(train_input2, train_target2, epoch_num, learning_rate, tol, optimize_type, batch_size, reg, bn_mode)
print('Accuracy')
print(accuracy_score(test_target2, model.predict(test_input2)))
print('Precision')
print(precision_score(test_target2, model.predict(test_input2)))
print('Recall')
print(recall_score(test_target2, model.predict(test_input2)))
print('f1_score')
print(f1_score(test_target2, model.predict(test_input2)))
model.plot_loss()
tool.plot_decision_boundary(np.array(dataSet2), np.array(labels2), model, 'layer3 few neuron')

layer_num = 3
unit_num = [12, 6, 1]
epoch_num = 100
learning_rate = 0.1
model = mlp.MLP(input_dim, layer_num, unit_num)
model.train(train_input2, train_target2, epoch_num, learning_rate, tol, optimize_type, batch_size, reg, bn_mode)
print('Accuracy')
print(accuracy_score(test_target2, model.predict(test_input2)))
print('Precision')
print(precision_score(test_target2, model.predict(test_input2)))
print('Recall')
print(recall_score(test_target2, model.predict(test_input2)))
print('f1_score')
print(f1_score(test_target2, model.predict(test_input2)))
model.plot_loss()
tool.plot_decision_boundary(np.array(dataSet2), np.array(labels2), model, 'layer3 few neuron')

layer_num = 6
unit_num = [15, 12, 9, 6, 3, 1]
learning_rate = 0.014
epoch_num = 1500
# loss 0.4多 1500次
model = mlp.MLP(input_dim, layer_num, unit_num)
model.train(train_input2, train_target2, epoch_num, learning_rate, tol, optimize_type, batch_size, reg, bn_mode)
model.plot_loss()
print('Accuracy')
print(accuracy_score(test_target2, model.predict(test_input2)))
print('Precision')
print(precision_score(test_target2, model.predict(test_input2)))
print('Recall')
print(recall_score(test_target2, model.predict(test_input2)))
print('f1_score')
print(f1_score(test_target2, model.predict(test_input2)))
tool.plot_decision_boundary(np.array(dataSet2), np.array(labels2), model, 'layer3 few neuron')

layer_num = 6
unit_num = [30, 24, 18, 6, 3, 1]
learning_rate = 0.06
epoch_num = 1000
#loss 0.434290 1000次
model = mlp.MLP(input_dim, layer_num, unit_num)
model.train(train_input2, train_target2, epoch_num, learning_rate, tol, optimize_type, batch_size, reg, bn_mode)
model.plot_loss()
print('Accuracy')
print(accuracy_score(test_target2, model.predict(test_input2)))
print('Precision')
print(precision_score(test_target2, model.predict(test_input2)))
print('Recall')
print(recall_score(test_target2, model.predict(test_input2)))
print('f1_score')
print(f1_score(test_target2, model.predict(test_input2)))
tool.plot_decision_boundary(np.array(dataSet2), np.array(labels2), model, 'layer3 few neuron')

layer_num = 9
unit_num = [60, 42, 36, 30, 24, 18, 6, 3, 1]
learning_rate = 0.001
epoch_num = 10000
model = mlp.MLP(input_dim, layer_num, unit_num)
model.train(train_input2, train_target2, epoch_num, learning_rate, tol, optimize_type, batch_size, reg, bn_mode)
model.plot_loss()
print('Accuracy')
print(accuracy_score(test_target2, model.predict(test_input2)))
print('Precision')
print(precision_score(test_target2, model.predict(test_input2)))
print('Recall')
print(recall_score(test_target2, model.predict(test_input2)))
print('f1_score')
print(f1_score(test_target2, model.predict(test_input2)))
tool.plot_decision_boundary(np.array(dataSet2), np.array(labels2), model, 'layer3 few neuron')

layer_num = 9
unit_num = [6, 18, 24, 30, 24, 18, 6, 3, 1]
learning_rate = 0.0012
epoch_num = 30000
model = mlp.MLP(input_dim, layer_num, unit_num)
model.train(train_input2, train_target2, epoch_num, learning_rate, tol, optimize_type, batch_size, reg, bn_mode)
model.plot_loss()
print('Accuracy')
print(accuracy_score(test_target2, model.predict(test_input2)))
print('Precision')
print(precision_score(test_target2, model.predict(test_input2)))
print('Recall')
print(recall_score(test_target2, model.predict(test_input2)))
print('f1_score')
print(f1_score(test_target2, model.predict(test_input2)))
tool.plot_decision_boundary(np.array(dataSet2), np.array(labels2), model, 'layer3 few neuron')
#loss 0.323417 训练15000
# Out:
# training linear data
# Finished epoch 100/1000: loss 0.004437, lr: 0.100000
# Finished epoch 200/1000: loss 0.001932, lr: 0.100000
# Finished epoch 300/1000: loss 0.001223, lr: 0.100000
# Finished epoch 400/1000: loss 0.000888, lr: 0.100000
# Finished epoch 500/1000: loss 0.000695, lr: 0.100000
# Finished epoch 600/1000: loss 0.000569, lr: 0.100000
# Finished epoch 700/1000: loss 0.000482, lr: 0.100000
# Finished epoch 800/1000: loss 0.000418, lr: 0.100000
# Finished epoch 900/1000: loss 0.000369, lr: 0.100000
# Finished epoch 1000/1000: loss 0.000330, lr: 0.100000
# Finished epoch 100/1000: loss 0.001429, lr: 0.100000
# Finished epoch 200/1000: loss 0.000692, lr: 0.100000
# Finished epoch 300/1000: loss 0.000454, lr: 0.100000
# Finished epoch 400/1000: loss 0.000339, lr: 0.100000
# Finished epoch 500/1000: loss 0.000270, lr: 0.100000
# Finished epoch 600/1000: loss 0.000225, lr: 0.100000
# Finished epoch 700/1000: loss 0.000192, lr: 0.100000
# ...
